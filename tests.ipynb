# %%
import board
reload(board)
# Out:
# <module 'board' from 'board.py'>

# %%
b = board.Board()

# %%
b.state
# Out:
#     armies  can_card  cav_card event_type  inf_card owner  region  turn
# 0        0       NaN       NaN     region       NaN  None       0     0
# 1        0       NaN       NaN     region       NaN  None       1     0
# 2        0       NaN       NaN     region       NaN  None       2     0
# 3        0       NaN       NaN     region       NaN  None       3     0
# 4        0       NaN       NaN     region       NaN  None       4     0
# 5        0       NaN       NaN     region       NaN  None       5     0
# 6        0       NaN       NaN     region       NaN  None       6     0
# 7        0       NaN       NaN     region       NaN  None       7     0
# 8        0       NaN       NaN     region       NaN  None       8     0
# 9        0       NaN       NaN     region       NaN  None       9     0
# 10       0       NaN       NaN     region       NaN  None      10     0
# 11       0       NaN       NaN     region       NaN  None      11     0
# ...

# %%
b
