# %%
import riskga
import player
reload(riskga), reload(player)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plot_args={'layout':(4,4), 'figsize':(12,6)}

# %%
# %%time
ga = riskga.PlayerPool(player.GeneticPlayer, ranking_iterations=1)
# Out:
# CPU times: user 48.6 s, sys: 38.6 ms, total: 48.7 s
# Wall time: 48.7 s

# %%
ga.save('test.save')

# %%
ga = riskga.PlayerPool.load(player.GeneticPlayer, 'test.save', ranking_iterations=2)

# %%
# %%time
ga.gene_df.hist(**plot_args)
plt.show()
for i in range(20):
    ga.iteration()
    ga.gene_df.hist(**plot_args)
    plt.show()
# Out:
# CPU times: user 51min 49s, sys: 4.61 s, total: 51min 54s
# Wall time: 51min 56s

# %%
# %%time
ga.gene_df.hist(**plot_args)
plt.show()
for i in range(20):
    ga.iteration()
    ga.gene_df.hist(**plot_args)
    plt.show()
# Out:
# CPU times: user 27min 21s, sys: 3.76 s, total: 27min 24s
# Wall time: 27min 27s

# %%
# %%time
ga.gene_df.hist(**plot_args)
plt.show()
for i in range(20):
    ga.iteration()
    ga.gene_df.hist(**plot_args)
    plt.show()
# Out:
# CPU times: user 22min 18s, sys: 2.86 s, total: 22min 21s
# Wall time: 22min 23s
