# %%
import riskga
import player
reload(riskga), reload(player)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot(ga):
    plot_args={'layout':(3, 8), 'figsize':(16,8)}
    ga.gene_df.drop('iteration', axis=1).hist(**plot_args)
    plt.show()
def run(ga, n):
    for i in range(n):
        ga.iteration()
        plot(ga)
    ga.save('risk.json')
    ga.save_log('risk.csv')

# %% [markdown]
# ### Initialize

# %%
# %%time
ga = riskga.PlayerPool(player.GeneticPlayer, ranking_iterations=15, pool_size=512)
plot(ga)
# Out:
# CPU times: user 2.79 s, sys: 64.1 ms, total: 2.85 s
# Wall time: 2.85 s

# %% [markdown]
# ### Run

# %%
# %%time
run(ga, 3)
# Out:
# CPU times: user 6h 3min 53s, sys: 33.5 s, total: 6h 4min 26s
# Wall time: 6h 4min 42s

# %%
# %%time
run(ga, 3)
# Out:
# CPU times: user 3h 55min 57s, sys: 22.9 s, total: 3h 56min 20s
# Wall time: 21h 29min 42s

# %%
# %%time
run(ga, 3)
# Out:
# CPU times: user 2h 32min 17s, sys: 15.5 s, total: 2h 32min 33s
# Wall time: 2h 32min 42s

# %%
# %%time
run(ga, 3)
# Out:
# CPU times: user 1h 12min 57s, sys: 8.11 s, total: 1h 13min 5s
# Wall time: 17h 23min 9s

# %%
# %%time
run(ga, 30)
# Out:
# CPU times: user 5h 15min 56s, sys: 28.6 s, total: 5h 16min 25s
# Wall time: 5h 16min 42s

# %%
# !ls -l
# Out:
# total 48520
# -rw-r--r--  1 rgeer  110268061     5291 May 23 15:21 README.md
# -rw-r--r--  1 rgeer  110268061    16661 Jun 27 09:00 board.py
# -rw-r--r--  1 rgeer  110268061    17989 Jun 30 09:07 board.pyc
# -rw-r--r--  1 rgeer  110268061     3531 Jun 27 09:00 cards.py
# -rw-r--r--  1 rgeer  110268061     4595 Jun 30 09:07 cards.pyc
# -rw-r--r--  1 rgeer  110268061      646 Jun 20 09:43 custom.css
# -rw-r--r--  1 rgeer  110268061     3962 May 30 09:04 definitions.py
# -rw-r--r--  1 rgeer  110268061     4380 May 30 13:15 definitions.pyc
# -rw-r--r--  1 rgeer  110268061  1542490 Jul  6 10:39 ga.ipynb
# -rw-r--r--  1 rgeer  110268061    10444 Jun 27 09:00 game.py
# -rw-r--r--  1 rgeer  110268061    10936 Jun 30 09:07 game.pyc
# -rw-r--r--  1 rgeer  110268061     6468 Jun 13 16:38 genome.py
# -rw-r--r--  1 rgeer  110268061     7692 Jun 13 16:42 genome.pyc
# -rw-r--r--  1 rgeer  110268061    88935 Jul  4 09:19 load_ga.ipynb
# -rw-r--r--  1 rgeer  110268061    53518 Jul  4 09:17 log.csv
# -rw-r--r--  1 rgeer  110268061     6560 May 31 14:49 missions.py
# -rw-r--r--  1 rgeer  110268061     9084 May 31 14:49 missions.pyc
# -rw-r--r--  1 rgeer  110268061  1796263 May  9 13:07 notebook-rogier.ipynb
# -rw-r--r--  1 rgeer  110268061  8806056 May  9 13:07 notebook.ipynb
# -rw-r--r--  1 rgeer  110268061       72 Jun 21 17:34 play_risk.ipynb
# -rw-r--r--  1 rgeer  110268061    19602 Jul  4 10:04 player.py
# -rw-r--r--  1 rgeer  110268061    18511 Jul  4 10:04 player.pyc
# -rw-r--r--  1 rgeer  110268061     4378 May 31 14:00 player_tester.pyc
# -rw-r--r--  1 rgeer  110268061   209385 May 31 16:45 player_testing.ipynb
# -rw-r--r--  1 rgeer  110268061  7361495 Jun 27 09:00 presentation.ipynb
# -rw-r--r--  1 rgeer  110268061    28754 Jun 16 11:36 probabilities.ipynb
# -rw-r--r--  1 rgeer  110268061     2946 Jun 13 11:08 ranker.py
# -rw-r--r--  1 rgeer  110268061     4504 Jun 13 11:10 ranker.pyc
# -rw-r--r--  1 rgeer  110268061      879 Jun  7 14:28 requirements.txt
# -rw-r--r--  1 rgeer  110268061  2644708 Jul  6 14:51 risk.csv
# -rw-r--r--  1 rgeer  110268061   283897 Jul  6 14:51 risk.json
# -rw-r--r--  1 rgeer  110268061  1664753 May  9 13:07 risk.png
# -rw-r--r--  1 rgeer  110268061    14695 May  9 13:07 risk.py
# -rw-r--r--  1 rgeer  110268061    15200 May 30 17:02 risk.pyc
# -rw-r--r--  1 rgeer  110268061     3526 May  9 13:07 risk_defs.py
# -rw-r--r--  1 rgeer  110268061      101 Jun  7 11:26 risk_ranker.pyc
# -rw-r--r--  1 rgeer  110268061     5055 May 31 16:44 risk_tester.py
# -rw-r--r--  1 rgeer  110268061     7142 May 31 16:44 risk_tester.pyc
# -rw-r--r--  1 rgeer  110268061     2077 Jul  4 10:04 riskga.py
# -rw-r--r--  1 rgeer  110268061     2892 Jul  4 10:04 riskga.pyc
# -rw-r--r--  1 rgeer  110268061     2649 May 30 14:33 test.ipynb
# -rw-r--r--  1 rgeer  110268061    19599 Jun 13 16:45 test.save
# -rw-r--r--  1 rgeer  110268061     8991 Jun 10 10:27 test_ranker.ipynb
# -rw-r--r--  1 rgeer  110268061    10702 May 11 08:14 test_risk.ipynb
# -rw-r--r--  1 rgeer  110268061     2057 May  9 13:07 tests.ipynb
# -rw-r--r--  1 rgeer  110268061     4710 Jun  7 14:31 trueskill.ipynb
# drwxr-xr-x  8 rgeer  110268061      272 May  9 13:08 venv

# %%
# %%time
run(ga, 30)

# %%
# %%time
run(ga, 30)
